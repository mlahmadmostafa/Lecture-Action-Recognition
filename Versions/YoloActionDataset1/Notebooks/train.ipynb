# %%
from ultralytics import YOLO
import torch
import torch.nn as nn
import sys
sys.path.append("../Scrpits/")
from yololstm import YOLO_LSTM
from dataloader import ActionLoad
from torch.utils.data import DataLoader
import os

# %%
from sklearn.model_selection import train_test_split
import pickle
with open('../Dataset/samples_df.pickle', 'rb') as file:
    samples_df = pickle.load(file)
train, test = train_test_split(samples_df, test_size=0.2, random_state=42, shuffle=True,stratify=samples_df["class_type"])
train, val = train_test_split(train, test_size=0.2, random_state=42)

train_list = [i for i in train["img_names"]]
val_list = [i for i in val["img_names"]]
test_list = [i for i in test["img_names"]]

train_dataset = ActionLoad(root_dir="../Dataset", samples_list_of_lists=train_list)
val_dataset = ActionLoad(root_dir="../Dataset", samples_list_of_lists=val_list)
test_dataset = ActionLoad(root_dir="../Dataset", samples_list_of_lists=test_list)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
from collections import Counter
label_counts = Counter(samples_df["class_type"])
num_classes = 5
total = sum(label_counts.values())
class_weights = [total / (num_classes * label_counts[i]) for i in label_counts.keys()]

# %%
from ultralytics import YOLO
from torchinfo import summary
yolo_model = YOLO('../Models/yoloaction.pt') 

backbone = yolo_model.model.model[:10]  # nn.ModuleList
model = YOLO_LSTM(yolo_backbone=backbone, hidden_size = 512)
# Verify by printing model info
summary(model, (1, 8, 3, 640, 640), device='cpu')
# Out:
# YOLO backbone trainable params: 0
# YOLO backbone extracted. Its last layer is: SPPF(
#   (cv1): Conv(
#     (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (cv2): Conv(
#     (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
# )
# DEBUG: Shape of dummy_backbone_output: torch.Size([1, 256, 20, 20])
# Dynamically determined YOLO backbone feature shape: (256, 20, 20)
# Calculated LSTM input dimension: 256 (C*H*W)
# LSTM initialized with hidden_size=512, num_layers=2
# Fully connected layer initialized with 512 -> 5 outputs
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# YOLO_LSTM                                          [1, 5]                    --
# ├─Sequential: 1-1                                  [1, 256, 20, 20]          --
# │    └─Conv: 2-1                                   [1, 16, 320, 320]         --
# │    │    └─Conv2d: 3-1                            [1, 16, 320, 320]         (432)
# │    │    └─BatchNorm2d: 3-2                       [1, 16, 320, 320]         (32)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-3                                   [1, 32, 160, 160]         --
# │    │    └─Conv2d: 3-4                            [1, 32, 160, 160]         (4,608)
# │    │    └─BatchNorm2d: 3-5                       [1, 32, 160, 160]         (64)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-5                                    [1, 32, 160, 160]         6,272
# │    │    └─Conv: 3-7                              [1, 32, 160, 160]         (1,088)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─Conv: 3-13                             [1, 32, 160, 160]         (1,600)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-13                                  [1, 64, 80, 80]           --
# │    │    └─Conv2d: 3-15                           [1, 64, 80, 80]           (18,432)
# │    │    └─BatchNorm2d: 3-16                      [1, 64, 80, 80]           (128)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-15                                   [1, 64, 80, 80]           45,440
# │    │    └─Conv: 3-18                             [1, 64, 80, 80]           (4,224)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─Conv: 3-28                             [1, 64, 80, 80]           (8,320)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-27                                  [1, 128, 40, 40]          --
# │    │    └─Conv2d: 3-30                           [1, 128, 40, 40]          (73,728)
# │    │    └─BatchNorm2d: 3-31                      [1, 128, 40, 40]          (256)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-29                                   [1, 128, 40, 40]          180,992
# │    │    └─Conv: 3-33                             [1, 128, 40, 40]          (16,640)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─Conv: 3-43                             [1, 128, 40, 40]          (33,024)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-41                                  [1, 256, 20, 20]          --
# │    │    └─Conv2d: 3-45                           [1, 256, 20, 20]          (294,912)
# │    │    └─BatchNorm2d: 3-46                      [1, 256, 20, 20]          (512)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-43                                   [1, 256, 20, 20]          394,240
# │    │    └─Conv: 3-48                             [1, 256, 20, 20]          (66,048)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─Conv: 3-54                             [1, 256, 20, 20]          (98,816)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─SPPF: 2-51                                  [1, 256, 20, 20]          --
# │    │    └─Conv: 3-56                             [1, 128, 20, 20]          (33,024)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    │    └─MaxPool2d: 3-58                        [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-59                        [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-60                        [1, 128, 20, 20]          --
# │    │    └─Conv: 3-61                             [1, 256, 20, 20]          (131,584)
# ├─AdaptiveAvgPool2d: 1-2                           [1, 256, 1, 1]            --
# ├─Sequential: 1-3                                  [1, 256, 20, 20]          (recursive)
# │    └─Conv: 2-52                                  [1, 16, 320, 320]         (recursive)
# │    │    └─Conv2d: 3-62                           [1, 16, 320, 320]         (recursive)
# │    │    └─BatchNorm2d: 3-63                      [1, 16, 320, 320]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-54                                  [1, 32, 160, 160]         (recursive)
# │    │    └─Conv2d: 3-65                           [1, 32, 160, 160]         (recursive)
# │    │    └─BatchNorm2d: 3-66                      [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-56                                   [1, 32, 160, 160]         (recursive)
# │    │    └─Conv: 3-68                             [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─Conv: 3-74                             [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-64                                  [1, 64, 80, 80]           (recursive)
# │    │    └─Conv2d: 3-76                           [1, 64, 80, 80]           (recursive)
# │    │    └─BatchNorm2d: 3-77                      [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-66                                   [1, 64, 80, 80]           (recursive)
# │    │    └─Conv: 3-79                             [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─Conv: 3-89                             [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-78                                  [1, 128, 40, 40]          (recursive)
# │    │    └─Conv2d: 3-91                           [1, 128, 40, 40]          (recursive)
# │    │    └─BatchNorm2d: 3-92                      [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-80                                   [1, 128, 40, 40]          (recursive)
# │    │    └─Conv: 3-94                             [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─Conv: 3-104                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-92                                  [1, 256, 20, 20]          (recursive)
# │    │    └─Conv2d: 3-106                          [1, 256, 20, 20]          (recursive)
# │    │    └─BatchNorm2d: 3-107                     [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-94                                   [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-109                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─Conv: 3-115                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─SPPF: 2-102                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-117                            [1, 128, 20, 20]          (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    │    └─MaxPool2d: 3-119                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-120                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-121                       [1, 128, 20, 20]          --
# │    │    └─Conv: 3-122                            [1, 256, 20, 20]          (recursive)
# ├─AdaptiveAvgPool2d: 1-4                           [1, 256, 1, 1]            --
# ├─Sequential: 1-5                                  [1, 256, 20, 20]          (recursive)
# │    └─Conv: 2-103                                 [1, 16, 320, 320]         (recursive)
# │    │    └─Conv2d: 3-123                          [1, 16, 320, 320]         (recursive)
# │    │    └─BatchNorm2d: 3-124                     [1, 16, 320, 320]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-105                                 [1, 32, 160, 160]         (recursive)
# │    │    └─Conv2d: 3-126                          [1, 32, 160, 160]         (recursive)
# │    │    └─BatchNorm2d: 3-127                     [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-107                                  [1, 32, 160, 160]         (recursive)
# │    │    └─Conv: 3-129                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─Conv: 3-135                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-115                                 [1, 64, 80, 80]           (recursive)
# │    │    └─Conv2d: 3-137                          [1, 64, 80, 80]           (recursive)
# │    │    └─BatchNorm2d: 3-138                     [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-117                                  [1, 64, 80, 80]           (recursive)
# │    │    └─Conv: 3-140                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─Conv: 3-150                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-129                                 [1, 128, 40, 40]          (recursive)
# │    │    └─Conv2d: 3-152                          [1, 128, 40, 40]          (recursive)
# │    │    └─BatchNorm2d: 3-153                     [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-131                                  [1, 128, 40, 40]          (recursive)
# │    │    └─Conv: 3-155                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─Conv: 3-165                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-143                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv2d: 3-167                          [1, 256, 20, 20]          (recursive)
# │    │    └─BatchNorm2d: 3-168                     [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-145                                  [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-170                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─Conv: 3-176                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─SPPF: 2-153                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-178                            [1, 128, 20, 20]          (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    │    └─MaxPool2d: 3-180                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-181                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-182                       [1, 128, 20, 20]          --
# │    │    └─Conv: 3-183                            [1, 256, 20, 20]          (recursive)
# ├─AdaptiveAvgPool2d: 1-6                           [1, 256, 1, 1]            --
# ├─Sequential: 1-7                                  [1, 256, 20, 20]          (recursive)
# │    └─Conv: 2-154                                 [1, 16, 320, 320]         (recursive)
# │    │    └─Conv2d: 3-184                          [1, 16, 320, 320]         (recursive)
# │    │    └─BatchNorm2d: 3-185                     [1, 16, 320, 320]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-156                                 [1, 32, 160, 160]         (recursive)
# │    │    └─Conv2d: 3-187                          [1, 32, 160, 160]         (recursive)
# │    │    └─BatchNorm2d: 3-188                     [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-158                                  [1, 32, 160, 160]         (recursive)
# │    │    └─Conv: 3-190                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─Conv: 3-196                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-166                                 [1, 64, 80, 80]           (recursive)
# │    │    └─Conv2d: 3-198                          [1, 64, 80, 80]           (recursive)
# │    │    └─BatchNorm2d: 3-199                     [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-168                                  [1, 64, 80, 80]           (recursive)
# │    │    └─Conv: 3-201                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─Conv: 3-211                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-180                                 [1, 128, 40, 40]          (recursive)
# │    │    └─Conv2d: 3-213                          [1, 128, 40, 40]          (recursive)
# │    │    └─BatchNorm2d: 3-214                     [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-182                                  [1, 128, 40, 40]          (recursive)
# │    │    └─Conv: 3-216                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─Conv: 3-226                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-194                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv2d: 3-228                          [1, 256, 20, 20]          (recursive)
# │    │    └─BatchNorm2d: 3-229                     [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-196                                  [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-231                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─Conv: 3-237                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─SPPF: 2-204                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-239                            [1, 128, 20, 20]          (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    │    └─MaxPool2d: 3-241                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-242                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-243                       [1, 128, 20, 20]          --
# │    │    └─Conv: 3-244                            [1, 256, 20, 20]          (recursive)
# ├─AdaptiveAvgPool2d: 1-8                           [1, 256, 1, 1]            --
# ├─Sequential: 1-9                                  [1, 256, 20, 20]          (recursive)
# │    └─Conv: 2-205                                 [1, 16, 320, 320]         (recursive)
# │    │    └─Conv2d: 3-245                          [1, 16, 320, 320]         (recursive)
# │    │    └─BatchNorm2d: 3-246                     [1, 16, 320, 320]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-207                                 [1, 32, 160, 160]         (recursive)
# │    │    └─Conv2d: 3-248                          [1, 32, 160, 160]         (recursive)
# │    │    └─BatchNorm2d: 3-249                     [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-209                                  [1, 32, 160, 160]         (recursive)
# │    │    └─Conv: 3-251                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─Conv: 3-257                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-217                                 [1, 64, 80, 80]           (recursive)
# │    │    └─Conv2d: 3-259                          [1, 64, 80, 80]           (recursive)
# │    │    └─BatchNorm2d: 3-260                     [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-219                                  [1, 64, 80, 80]           (recursive)
# │    │    └─Conv: 3-262                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─Conv: 3-272                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-231                                 [1, 128, 40, 40]          (recursive)
# │    │    └─Conv2d: 3-274                          [1, 128, 40, 40]          (recursive)
# │    │    └─BatchNorm2d: 3-275                     [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-233                                  [1, 128, 40, 40]          (recursive)
# │    │    └─Conv: 3-277                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# ...
# │    └─Conv: 2-333                                 [1, 128, 40, 40]          (recursive)
# │    │    └─Conv2d: 3-396                          [1, 128, 40, 40]          (recursive)
# │    │    └─BatchNorm2d: 3-397                     [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-335                                  [1, 128, 40, 40]          (recursive)
# │    │    └─Conv: 3-399                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─Conv: 3-409                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-347                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv2d: 3-411                          [1, 256, 20, 20]          (recursive)
# │    │    └─BatchNorm2d: 3-412                     [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-349                                  [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-414                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─Conv: 3-420                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─SPPF: 2-357                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-422                            [1, 128, 20, 20]          (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    │    └─MaxPool2d: 3-424                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-425                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-426                       [1, 128, 20, 20]          --
# │    │    └─Conv: 3-427                            [1, 256, 20, 20]          (recursive)
# ├─AdaptiveAvgPool2d: 1-14                          [1, 256, 1, 1]            --
# ├─Sequential: 1-15                                 [1, 256, 20, 20]          (recursive)
# │    └─Conv: 2-358                                 [1, 16, 320, 320]         (recursive)
# │    │    └─Conv2d: 3-428                          [1, 16, 320, 320]         (recursive)
# │    │    └─BatchNorm2d: 3-429                     [1, 16, 320, 320]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-360                                 [1, 32, 160, 160]         (recursive)
# │    │    └─Conv2d: 3-431                          [1, 32, 160, 160]         (recursive)
# │    │    └─BatchNorm2d: 3-432                     [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-362                                  [1, 32, 160, 160]         (recursive)
# │    │    └─Conv: 3-434                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─ModuleList: 3-438                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-368                                  --                        (recursive)
# │    │    └─Conv: 3-440                            [1, 32, 160, 160]         (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-370                                 [1, 64, 80, 80]           (recursive)
# │    │    └─Conv2d: 3-442                          [1, 64, 80, 80]           (recursive)
# │    │    └─BatchNorm2d: 3-443                     [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-372                                  [1, 64, 80, 80]           (recursive)
# │    │    └─Conv: 3-445                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─ModuleList: 3-453                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-382                                  --                        (recursive)
# │    │    └─Conv: 3-455                            [1, 64, 80, 80]           (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-384                                 [1, 128, 40, 40]          (recursive)
# │    │    └─Conv2d: 3-457                          [1, 128, 40, 40]          (recursive)
# │    │    └─BatchNorm2d: 3-458                     [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-386                                  [1, 128, 40, 40]          (recursive)
# │    │    └─Conv: 3-460                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─ModuleList: 3-468                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-396                                  --                        (recursive)
# │    │    └─Conv: 3-470                            [1, 128, 40, 40]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─Conv: 2-398                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv2d: 3-472                          [1, 256, 20, 20]          (recursive)
# │    │    └─BatchNorm2d: 3-473                     [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-400                                  [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-475                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─ModuleList: 3-479                      --                        (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─C2f: 2-406                                  --                        (recursive)
# │    │    └─Conv: 3-481                            [1, 256, 20, 20]          (recursive)
# │    └─SPPF: 2-407                                 --                        (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    └─SPPF: 2-408                                 [1, 256, 20, 20]          (recursive)
# │    │    └─Conv: 3-483                            [1, 128, 20, 20]          (recursive)
# │    │    └─Conv: 3-484                            --                        (recursive)
# │    │    └─MaxPool2d: 3-485                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-486                       [1, 128, 20, 20]          --
# │    │    └─MaxPool2d: 3-487                       [1, 128, 20, 20]          --
# │    │    └─Conv: 3-488                            [1, 256, 20, 20]          (recursive)
# ├─AdaptiveAvgPool2d: 1-16                          [1, 256, 1, 1]            --
# ├─LSTM: 1-17                                       [1, 8, 512]               3,678,208
# ├─Linear: 1-18                                     [1, 5]                    2,565
# ====================================================================================================
# Total params: 5,822,965
# Trainable params: 3,680,773
# Non-trainable params: 2,142,192
# Total mult-adds (Units.GIGABYTES): 12.65
# ====================================================================================================
# Input size (MB): 39.32
# Forward/backward pass size (MB): 1094.48
# Params size (MB): 19.81
# Estimated Total Size (MB): 1153.62
# ====================================================================================================

# %%
total = 0
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"{name}: {param.numel():,}")
        total += param.numel()
print(f"Total trainable params: {total:,}")
# Out:
# lstm.weight_ih_l0: 524,288
# lstm.weight_hh_l0: 1,048,576
# lstm.bias_ih_l0: 2,048
# lstm.bias_hh_l0: 2,048
# lstm.weight_ih_l1: 1,048,576
# lstm.weight_hh_l1: 1,048,576
# lstm.bias_ih_l1: 2,048
# lstm.bias_hh_l1: 2,048
# fc.weight: 2,560
# fc.bias: 5
# Total trainable params: 3,680,773

# %%
def calculate_accuracy(preds, labels):
    _, predicted = torch.max(preds, dim=1)
    correct = (predicted == labels).sum().item()
    total = labels.size(0)
    return correct / total
from torch.utils.tensorboard import SummaryWriter

# %%
from time import time, strftime, localtime
from IPython.display import clear_output
def train(model, train_loader, val_loader, criterion, optimizer, device, epochs=10):
    now = localtime(time())
    now = strftime("%m-%d_%H_%M", now)
    writer = SummaryWriter(f"Logs/{now}/")
    model.to(device)
    best_val_acc = 0.0
    def train_one_epoch(epoch):
        model.train()
        total_loss, total_acc = 0.0, 0.0
        for step, (x_seq, label) in enumerate(train_loader):
            # Ensure input shape: (B, 8, 3, 640, 640)
            x_seq = x_seq.unsqueeze(0).to(device) if x_seq.ndim == 4 else x_seq.to(device)  # (B=1, 8, 3, 640, 640)
            label = label.to(device)

            optimizer.zero_grad()
            outputs = model(x_seq)
            loss = criterion(outputs, label)
            loss.backward()
            optimizer.step()

            acc = calculate_accuracy(outputs, label)
            total_loss += loss.item()
            total_acc += acc

            print(f"[Train Step {step}/{len(train_loader)}] Loss: {loss.item():.4f}, Acc: {acc:.4f}")
            clear_output(wait=True)
            writer.add_scalars("Train", {
                "Loss": loss.item(),
                "Accuracy": acc
            }, epoch*len(train_loader)+step)
            writer.flush()

        avg_loss = total_loss / len(train_loader)
        avg_acc = total_acc / len(train_loader)
        writer.add_scalars("Epoch", {
            "Loss": avg_loss,
            "Accuracy": avg_acc
        }, epoch)
        writer.flush()

        print(f"[Epoch {epoch}/{epochs}] Train Loss: {avg_loss:.4f}, Accuracy: {avg_acc:.4f}")
        
    def validate(epoch, best_val_acc):

        model.eval()
        val_loss, val_acc = 0.0, 0.0

        with torch.no_grad():
            for x_seq, label in val_loader:
                x_seq = x_seq.unsqueeze(0).to(device) if x_seq.ndim == 4 else x_seq.to(device)
                label = label.to(device)

                outputs = model(x_seq)
                loss = criterion(outputs, label)
                acc = calculate_accuracy(outputs, label)

                val_loss += loss.item()
                val_acc += acc.item() if isinstance(acc, torch.Tensor) else acc
        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), '../Models/best_yololstm.pth')
            print(f"✅ Saved new best model with val_acc: {val_acc:.4f}")
        avg_loss = val_loss / len(val_loader)
        avg_acc = val_acc / len(val_loader)
        writer.add_scalars("Validation", {
            "Loss": avg_loss,
            "Accuracy": avg_acc
        }, epoch)
        writer.flush()

        print(f"[Epoch {epoch}/{epochs}] Val Loss: {avg_loss:.4f}, Accuracy: {avg_acc:.4f}")

    for epoch in range(epochs):
        train_one_epoch(epoch)
        validate(epoch, best_val_acc)

    writer.close()

# %%
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
try:
    train(model, train_dataloader, val_dataloader, criterion, optimizer, device, epochs=10)
except KeyboardInterrupt:
    print("Training interrupted by user.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       7 criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
#       8 optimizer = optim.Adam(model.parameters(), lr=1e-4)
# ----> 9 train(model, train_dataloader, val_dataloader, criterion, optimizer, device, epochs=10)
#
# Cell In[7], line 77, in train(model, train_loader, val_loader, criterion, optimizer, device, epochs)
#      74     print(f"[Epoch {epoch}/{epochs}] Val Loss: {avg_loss:.4f}, Accuracy: {avg_acc:.4f}")
#      76 for epoch in range(epochs):
# ---> 77     train_one_epoch(epoch)
#      78     validate(epoch, best_val_acc)
#      80 writer.close()
#
# Cell In[7], line 12, in train.<locals>.train_one_epoch(epoch)
#      10 model.train()
#      11 total_loss, total_acc = 0.0, 0.0
# ---> 12 for step, (x_seq, label) in enumerate(train_loader):
#      13     # Ensure input shape: (B, 8, 3, 640, 640)
#      14     x_seq = x_seq.unsqueeze(0).to(device) if x_seq.ndim == 4 else x_seq.to(device)  # (B=1, 8, 3, 640, 640)
#      15     label = label.to(device)
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File d:\Industry\Corporate\Freelance\Mohamed Hazem - YoloAction\Project\Notebooks\../Scrpits\dataloader.py:49, in ActionLoad.__getitem__(self, idx)
#      47 annotations = []
#      48 for image_name in self.samples_map[idx]:
# ---> 49     image, anno = self.get_image(image_name)
#      50     images.append(image)
#      51     annotations.append(anno)
#
# File d:\Industry\Corporate\Freelance\Mohamed Hazem - YoloAction\Project\Notebooks\../Scrpits\dataloader.py:40, in ActionLoad.get_image(self, image_name)
#      38 image_name = image_name.split('.')[0]
#      39 image = Image.open(f"{self.root_dir}/PPDataset/train/images/{image_name}.jpg")
# ---> 40 image = preprocess_image_for_yolo_backbone(image)
#      41 with open(f"{self.root_dir}/PPDataset/train/labels/{image_name}.txt", 'r') as file:
#      42     anno = torch.tensor(int(file.read().split(' ')[0]), dtype=torch.long)
#
# File d:\Industry\Corporate\Freelance\Mohamed Hazem - YoloAction\Project\Notebooks\../Scrpits\dataloader.py:23, in preprocess_image_for_yolo_backbone(img)
#      10 def preprocess_image_for_yolo_backbone(img):
#      11     """
#      12     Loads an image, preprocesses it for a YOLO backbone (RGB, resized, normalized),
#      13     and returns it as a PyTorch tensor.
#    (...)
#      21                       Returns None if image loading fails.
#      22     """
# ---> 23     img = np.array(img)
#      24     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      25     img = torch.from_numpy(img).permute(2, 0, 1).float()
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\PIL\Image.py:756, in Image.__array_interface__(self)
#     754     new["data"] = self.tobytes("raw", "L")
#     755 else:
# --> 756     new["data"] = self.tobytes()
#     757 new["shape"], new["typestr"] = _conv_type_shape(self)
#     758 return new
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\PIL\Image.py:805, in Image.tobytes(self, encoder_name, *args)
#     802 if encoder_name == "raw" and encoder_args == ():
#     803     encoder_args = self.mode
# --> 805 self.load()
#     807 if self.width == 0 or self.height == 0:
#     808     return b""
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\PIL\ImageFile.py:280, in ImageFile.load(self)
#     278 while True:
#     279     try:
# --> 280         s = read(self.decodermaxblock)
#     281     except (IndexError, struct.error) as e:
#     282         # truncated png/gif
#     283         if LOAD_TRUNCATED_IMAGES:
#
# File d:\program_files\anaconda3\envs\torch_gpu\Lib\site-packages\PIL\JpegImagePlugin.py:404, in JpegImageFile.load_read(self, read_bytes)
#     398 def load_read(self, read_bytes: int) -> bytes:
#     399     """
#     400     internal: read more image data
#     401     For premature EOF and LOAD_TRUNCATED_IMAGES adds EOI marker
#     402     so libjpeg can finish decoding
#     403     """
# --> 404     s = self.fp.read(read_bytes)
#     406     if not s and ImageFile.LOAD_TRUNCATED_IMAGES and not hasattr(self, "_ended"):
#     407         # Premature EOF.
#     408         # Pretend file is finished adding EOI marker
#     409         self._ended = True
#
# KeyboardInterrupt:

# %%
def test_model(model, test_loader, criterion, device):
    model.eval()
    test_loss, test_acc = 0.0, 0.0

    with torch.no_grad():
        for x_seq, label in test_loader:
            x_seq = x_seq.unsqueeze(0).to(device) if x_seq.ndim == 4 else x_seq.to(device)
            label = label.to(device)

            outputs = model(x_seq)
            loss = criterion(outputs, label)
            acc = calculate_accuracy(outputs, label)

            test_loss += loss.item()
            test_acc += acc

    avg_loss = test_loss / len(test_loader)
    avg_acc = test_acc / len(test_loader)
    print(f"[Test] Loss: {avg_loss:.4f}, Accuracy: {avg_acc:.4f}")

# %%
test_model(model, test_dataloader, criterion, device)
# Out:
# [Test] Loss: 0.0188, Accuracy: 0.9972

# %%
len(train_list), len(val_list), len(test_list)
# Out:
# (1027, 257, 322)

# %%
from time import time
x = torch.rand((1, 8, 3, 640, 640)).to(device)
times = []
for i in range(100):
    start = time()
    y = model(x)
    end = time()
    times.append(end-start)
print(f"Average time: {sum(times)/len(times):.4f} Seconds")
# Out:
# Average time: 0.0451 Seconds

# %%
from time import time
x = torch.rand((1, 8, 3, 640, 640)).to("cpu")
model_cpu = model.to("cpu")
times = []
for i in range(10):
    start = time()
    y = model_cpu(x)
    end = time()
    times.append(end-start)
print(f"Average time: {sum(times)/len(times):.4f} Seconds")
# Out:
# Average time: 0.6328 Seconds
